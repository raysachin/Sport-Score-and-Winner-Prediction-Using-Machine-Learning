# %%
import numpy as np
import pandas as pd

# %%
match = pd.read_csv('../dataset/matches.csv')
delivery = pd.read_csv('../dataset/deliveries.csv')

# %%
match.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
match['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
match['team1'] = match['team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match['team2'] = match['team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')

match['team1'] = match['team1'].str.replace('Deccan Chargers', 'Sunrises Hyderabad')
match['team2'] = match['team2'].str.replace('Deccan Chargers', 'Sunrises Hyderabad')

match['team1'] = match['team1'].str.replace('Gujarat Lions', 'Gujarat Titans')
match['team2'] = match['team2'].str.replace('Gujarat Lions', 'Gujarat Titans')

match['team1'] = match['team1'].str.replace('Rising Pune Supergiants', 'Lucknow Super Giants')
match['team2'] = match['team2'].str.replace('Rising Pune Supergiants', 'Lucknow Super Giants')

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
delivery['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
delivery['batting_team'] = delivery['batting_team'].str.replace('Delhi Daredevils', 'Delhi Capitals')
delivery['bowling_team'] = delivery['bowling_team'].str.replace('Delhi Daredevils', 'Delhi Capitals')

delivery['batting_team'] = delivery['batting_team'].str.replace('Deccan Chargers', 'Sunrises Hyderabad')
delivery['bowling_team'] = delivery['bowling_team'].str.replace('Deccan Chargers', 'Sunrises Hyderabad')

delivery['batting_team'] = delivery['batting_team'].str.replace('Gujarat Lions', 'Gujarat Titans')
delivery['bowling_team'] = delivery['bowling_team'].str.replace('Gujarat Lions', 'Gujarat Titans')

delivery['batting_team'] = delivery['batting_team'].str.replace('Rising Pune Supergiants', 'Lucknow Super Giants')
delivery['bowling_team'] = delivery['bowling_team'].str.replace('Rising Pune Supergiants', 'Lucknow Super Giants')

# %%
match.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017               Gujarat Titans
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4               Delhi Capitals  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
delivery.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
match.shape
# Out:
# (756, 18)

# %% [markdown]
# ###  we required different format of data for applying machine learning model, so we extract and modify our data set from this datset

# %% [markdown]
# ### Aim: we have to find the probabilityof winning a team that play in 2nd inning on the basis of factor such as "Run Required", "Over left", "wicket left", "total runs", "current run rate", "required run rate" and the final result

# %% [markdown]
# ### This is classification problem but we want output in percentage form so that we have to choose that algorithm which give classification result in percentage or probability form
#
# **Algorithm such as logistic regression, support vector machine etc**

# %% [markdown]
# # Data Extraction

# %% [markdown]
# **We have to find total run score by a team in an innings, for this we will use group by and find sum of total runs in each ball**

# %%
delivery.groupby(['match_id', 'inning',]).sum()['total_runs']
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\1346125434.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   delivery.groupby(['match_id', 'inning',]).sum()['total_runs']
# match_id  inning
# 1         1         207
#           2         172
# 2         1         184
#           2         187
# 3         1         183
#                    ...
# 11413     2         170
# 11414     1         155
#           2         162
# 11415     1         152
#           2         157
# Name: total_runs, Length: 1528, dtype: int64

# %% [markdown]
# **To convert this into data frame we use "reset_index()" method**

# %%
total_score_df = delivery.groupby(['match_id', 'inning',]).sum()['total_runs'].reset_index()
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\822603834.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_score_df = delivery.groupby(['match_id', 'inning',]).sum()['total_runs'].reset_index()

# %% [markdown]
# **WE add +1 because chased run is 1 more than the actual run and we are chasing**

# %%
total_score_df['total_runs'] = total_score_df['total_runs'] + 1

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         208
# 1            1       2         173
# 2            2       1         185
# 3            2       2         188
# 4            3       1         184
# ...        ...     ...         ...
# 1523     11413       2         171
# 1524     11414       1         156
# 1525     11414       2         163
# 1526     11415       1         153
# 1527     11415       2         158
#
# [1528 rows x 3 columns]

# %% [markdown]
# **Extract out those row whose value of innings is 2**
#
# **Only we need to store the inning 1 of data**

# %%
total_score_df = total_score_df[total_score_df['inning'] == 1]

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         208
# 2            2       1         185
# 4            3       1         184
# 6            4       1         164
# 8            5       1         158
# ...        ...     ...         ...
# 1518     11347       1         144
# 1520     11412       1         137
# 1522     11413       1         172
# 1524     11414       1         156
# 1526     11415       1         153
#
# [756 rows x 3 columns]

# %% [markdown]
# **Now we have to merge "total_score_df" data set with "matches" dataset.**
#
# common column : match_id and id

# %%
match_df = match.merge(total_score_df[['match_id', 'total_runs']], left_on = 'id', right_on = 'match_id')

# %%
match_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017               Gujarat Titans
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4               Delhi Capitals  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ### Data preprocessing
# #### There are those team too in dataset who do not playt currently so we remove those team from the dataset

# %% [markdown]
# **convert "Delhi Daredevils" to "Delhi Capitals", "Deccan chargers" to "sunrises hyderabad",  "Gujarat Lions" to "Gujarat Titans"**

# %% [markdown]
# **Find total unique team**

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Titans',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Capitals', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Sunrises Hyderabad',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Lucknow Super Giants'],
#       dtype=object)

# %%
match_df['team2'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Capitals',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Titans',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Sunrises Hyderabad',
#        'Pune Warriors', 'Kochi Tuskers Kerala', 'Lucknow Super Giants'],
#       dtype=object)

# %% [markdown]
# **make a list of all unique team**

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Gujarat Titans',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals',
    'Lucknow Super Giants'
]

# %%
match_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017               Gujarat Titans
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4               Delhi Capitals  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# **Now, we put only those teams in dataset which is in our list of teams**

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 2        3  IPL-2017         Rajkot  07-04-2017               Gujarat Titans
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 5        6  IPL-2017      Hyderabad  09-04-2017               Gujarat Titans
# 6        7  IPL-2017         Mumbai  09-04-2017        Kolkata Knight Riders
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df.shape
# Out:
# (611, 20)

# %% [markdown]
# **Remove that match in which dl_method is applied**

# %%
match_df['dl_applied'].value_counts()
# Out:
# 0    593
# 1     18
# Name: dl_applied, dtype: int64

# %%
match_df = match_df[match_df['dl_applied'] == 0]

# %% [markdown]
# match_df

# %% [markdown]
# **Till now, we are done with**
#
# 1. Only those match are in dataset that is currently played.
# 2. removed those matvhes in which dl_applied

# %% [markdown]
# **Take out that columns that is needed and join it with delivery dataset**

# %%
match_df = match_df[['match_id', 'city', 'winner', 'total_runs']]

# %% [markdown]
# **join it with delivery dataset**

# %%
delivery_df = match_df.merge(delivery, on = 'match_id')

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 0              1  Hyderabad  Sunrisers Hyderabad           208       1
# 1              1  Hyderabad  Sunrisers Hyderabad           208       1
# 2              1  Hyderabad  Sunrisers Hyderabad           208       1
# 3              1  Hyderabad  Sunrisers Hyderabad           208       1
# 4              1  Hyderabad  Sunrisers Hyderabad           208       1
# ...          ...        ...                  ...           ...     ...
# 141509     11415  Hyderabad       Mumbai Indians           153       2
# 141510     11415  Hyderabad       Mumbai Indians           153       2
# 141511     11415  Hyderabad       Mumbai Indians           153       2
# 141512     11415  Hyderabad       Mumbai Indians           153       2
# 141513     11415  Hyderabad       Mumbai Indians           153       2
#
#                batting_team                 bowling_team  over  ball  \
# ...

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Gujarat Titans', 'Kolkata Knight Riders', 'Delhi Capitals',
#        'Mumbai Indians', 'Kings XI Punjab', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Lucknow Super Giants'], dtype=object)

# %% [markdown]
# **In delivery data set, we need only that value where inning == 2**

# %%
delivery_df = delivery_df[delivery_df['inning'] == 2]

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 141509     11415  Hyderabad       Mumbai Indians           153       2
# 141510     11415  Hyderabad       Mumbai Indians           153       2
# 141511     11415  Hyderabad       Mumbai Indians           153       2
# 141512     11415  Hyderabad       Mumbai Indians           153       2
# 141513     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivery_df.shape
# Out:
# (68415, 24)

# %% [markdown]
# **Now we have to extract out runs_left, balls_left, wicket_left, crr and rrr etc**
#
# **'total_runs_y' column gives the run after each ball so we find out the score after each ball by adding previous run scored on each ball**
#
# **for this we apply a function cumalitive sum on 'total_run_x' column**

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y']
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\3025607697.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   delivery_df['current_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y']
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\3025607697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y']

# %%
delivery_df['current_score']
# Out:
# 125         1
# 126         1
# 127         1
# 128         3
# 129         7
#          ...
# 141509    152
# 141510    154
# 141511    155
# 141512    157
# 141513    157
# Name: current_score, Length: 68415, dtype: int64

# %% [markdown]
# **Now we add a new column to find run left after each delivery**
#
# **Runs_left = total_runs - current_runs**

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\1162889266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 141509     11415  Hyderabad       Mumbai Indians           153       2
# 141510     11415  Hyderabad       Mumbai Indians           153       2
# 141511     11415  Hyderabad       Mumbai Indians           153       2
# 141512     11415  Hyderabad       Mumbai Indians           153       2
# 141513     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# **Now we have to find balls_left after each delivery**

# %%
delivery_df['balls_left'] = 120 - ((delivery_df['over']-1)*6 + delivery_df['ball'])
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\1633346659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['balls_left'] = 120 - ((delivery_df['over']-1)*6 + delivery_df['ball'])

# %% [markdown]
# **Now we have to find wicket left, for this there is no direct dismissiol in int case**
#
# **so the row NaN gives us no dismissal and row with player name gives us dismissal**
#
# **so we replace NaN by 0 and other by 1**
#
# **Then convert into int and then apply cumsum()**

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\2400862059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\2400862059.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 141509     11415  Hyderabad       Mumbai Indians           153       2
# 141510     11415  Hyderabad       Mumbai Indians           153       2
# 141511     11415  Hyderabad       Mumbai Indians           153       2
# 141512     11415  Hyderabad       Mumbai Indians           153       2
# 141513     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# **convert into int**

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\1121782170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')

# %%
wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\3074573211.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values

# %%
delivery_df['wicket_left'] = 10 - wickets
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\2870077134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['wicket_left'] = 10 - wickets

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 141509     11415  Hyderabad       Mumbai Indians           153       2
# 141510     11415  Hyderabad       Mumbai Indians           153       2
# 141511     11415  Hyderabad       Mumbai Indians           153       2
# 141512     11415  Hyderabad       Mumbai Indians           153       2
# 141513     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# **To find current run_rate**
#
# crr = runs/over_played

# %%
delivery_df['crr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\2048085250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['crr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])

# %% [markdown]
# **To find required run_rate**
#
# rrr = runs left/ over left

# %%
delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\2241449921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 141509     11415  Hyderabad       Mumbai Indians           153       2
# 141510     11415  Hyderabad       Mumbai Indians           153       2
# 141511     11415  Hyderabad       Mumbai Indians           153       2
# 141512     11415  Hyderabad       Mumbai Indians           153       2
# 141513     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# **Results in the terms of 0 and 1**
#
# **Logic = if winner_team == batting_team then 1 else 0**

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result, axis = 1)
# Out:
# C:\Users\sachin kumar ray\AppData\Local\Temp\ipykernel_20948\140305760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['result'] = delivery_df.apply(result, axis = 1)

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 141509     11415  Hyderabad       Mumbai Indians           153       2
# 141510     11415  Hyderabad       Mumbai Indians           153       2
# 141511     11415  Hyderabad       Mumbai Indians           153       2
# 141512     11415  Hyderabad       Mumbai Indians           153       2
# 141513     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# **Arrange the column as of our need**

# %%
final_df = delivery_df[['batting_team', 'bowling_team', 'city', 'runs_left', 'balls_left', 'wicket_left', 'total_runs_x', 'crr', 'rrr', 'result']]

# %%
final_df
# Out:
#                        batting_team         bowling_team       city  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                             ...                  ...        ...
# 141509          Chennai Super Kings       Mumbai Indians  Hyderabad
# 141510          Chennai Super Kings       Mumbai Indians  Hyderabad
# 141511          Chennai Super Kings       Mumbai Indians  Hyderabad
# 141512          Chennai Super Kings       Mumbai Indians  Hyderabad
# 141513          Chennai Super Kings       Mumbai Indians  Hyderabad
#
#         runs_left  balls_left  wicket_left  total_runs_x       crr        rrr  \
# ...

# %%
final_df['batting_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kolkata Knight Riders',
#        'Delhi Capitals', 'Sunrisers Hyderabad', 'Mumbai Indians',
#        'Kings XI Punjab', 'Gujarat Titans', 'Rajasthan Royals',
#        'Chennai Super Kings', 'Lucknow Super Giants'], dtype=object)

# %%
final_df['batting_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kolkata Knight Riders',
#        'Delhi Capitals', 'Sunrisers Hyderabad', 'Mumbai Indians',
#        'Kings XI Punjab', 'Gujarat Titans', 'Rajasthan Royals',
#        'Chennai Super Kings', 'Lucknow Super Giants'], dtype=object)

# %% [markdown]
# **Here we get our resultant dataset according to our use**

# %% [markdown]
# **Now shuffle the data so thast there is no biasesing in the model**

# %%
final_df = final_df.sample(final_df.shape[0])

# %% [markdown]
# **For any random match**

# %%
final_df.sample()
# Out:
#          batting_team     bowling_team  city  runs_left  balls_left  \
# 89318  Delhi Capitals  Kings XI Punjab  Pune        112          75
#
#        wicket_left  total_runs_x  crr   rrr  result
# 89318            8           166  7.2  8.96       0

# %% [markdown]
# **In our dataset there is a lot pf null value so we want to replace it and some value in rrr tends to infinity because ball left is 0 and run is something so (run/0) will gives the infinity result**

# %%
final_df.describe()
# Out:
#           runs_left    balls_left   wicket_left  total_runs_x           crr  \
# count  68415.000000  68415.000000  68415.000000  68415.000000  68415.000000
# mean      93.437477     62.762903      7.565168    167.275890      7.502539
# std       50.512047     33.357809      2.129731     29.657393      2.277276
# min      -15.000000     -2.000000      0.000000     66.000000      0.000000
# 25%       53.000000     35.000000      6.000000    148.000000      6.309278
# 50%       93.000000     63.000000      8.000000    166.000000      7.542857
# 75%      131.000000     92.000000      9.000000    187.000000      8.769231
# max      250.000000    119.000000     10.000000    251.000000     42.000000
#
#                 rrr        result
# count  6.841000e+04  68415.000000
# mean            NaN      0.472075
# std             NaN      0.499223
# min            -inf      0.000000
# 25%    7.200000e+00      0.000000
# 50%    8.968421e+00      0.000000
# 75%    1.101897e+01      1.000000
# ...

# %%
final_df.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city            832
# runs_left         0
# balls_left        0
# wicket_left       0
# total_runs_x      0
# crr               0
# rrr               5
# result            0
# dtype: int64

# %%
final_df.dropna(inplace = True)

# %%
final_df = final_df[final_df['balls_left'] != 0]

# %%
final_df
# Out:
#                  batting_team                 bowling_team           city  \
# 56665          Delhi Capitals  Royal Challengers Bangalore          Delhi
# 84315     Sunrisers Hyderabad          Chennai Super Kings         Ranchi
# 134135    Chennai Super Kings        Kolkata Knight Riders        Kolkata
# 41413   Kolkata Knight Riders             Rajasthan Royals        Kolkata
# 54072          Mumbai Indians          Chennai Super Kings         Mumbai
# ...                       ...                          ...            ...
# 465     Kolkata Knight Riders               Gujarat Titans         Rajkot
# 137835    Chennai Super Kings               Mumbai Indians        Chennai
# 64675        Rajasthan Royals          Sunrisers Hyderabad         Jaipur
# 141179    Chennai Super Kings               Delhi Capitals  Visakhapatnam
# 37226        Rajasthan Royals               Mumbai Indians         Jaipur
#
#         runs_left  balls_left  wicket_left  total_runs_x        crr  \
# ...

# %%
final_df.describe()
# Out:
#           runs_left    balls_left   wicket_left  total_runs_x           crr  \
# count  67363.000000  67363.000000  67363.000000  67363.000000  67363.000000
# mean      93.803438     62.981622      7.582530    167.436709      7.512190
# std       50.459510     33.214445      2.115584     29.669694      2.281639
# min      -15.000000     -2.000000      0.000000     66.000000      0.000000
# 25%       54.000000     35.000000      6.000000    149.000000      6.320000
# 50%       93.000000     64.000000      8.000000    166.000000      7.552941
# 75%      131.000000     92.000000      9.000000    187.000000      8.787879
# max      250.000000    119.000000     10.000000    251.000000     42.000000
#
#                 rrr        result
# count  67363.000000  67363.000000
# mean      10.539944      0.474014
# std       14.116584      0.499328
# min     -516.000000      0.000000
# 25%        7.200000      0.000000
# 50%        8.969072      0.000000
# 75%       11.000000      1.000000
# ...

# %% [markdown]
# # Model building

# %% [markdown]
# **Divide into independent and dependent variable**

# %%
X = final_df.iloc[:, :-1]
Y = final_df.iloc[:, -1]

# %% [markdown]
# **split into training set**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 1)

# %%
X_test
# Out:
#                        batting_team                 bowling_team       city  \
# 58168         Kolkata Knight Riders          Chennai Super Kings    Chennai
# 92203           Sunrisers Hyderabad               Mumbai Indians     Mumbai
# 137854          Chennai Super Kings               Mumbai Indians    Chennai
# 132037               Delhi Capitals  Royal Challengers Bangalore  Bengaluru
# 13913                Delhi Capitals               Mumbai Indians     Mumbai
# ...                             ...                          ...        ...
# 49198              Rajasthan Royals               Mumbai Indians     Mumbai
# 104420               Gujarat Titans  Royal Challengers Bangalore     Rajkot
# 16441                Mumbai Indians          Chennai Super Kings     Mumbai
# 40037                Mumbai Indians               Delhi Capitals      Delhi
# 91520   Royal Challengers Bangalore          Chennai Super Kings  Bangalore
#
# ...

# %%
X_test['batting_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Sunrisers Hyderabad',
#        'Chennai Super Kings', 'Delhi Capitals', 'Kings XI Punjab',
#        'Rajasthan Royals', 'Mumbai Indians',
#        'Royal Challengers Bangalore', 'Lucknow Super Giants',
#        'Gujarat Titans'], dtype=object)

# %%
X_train
# Out:
#                        batting_team                 bowling_team        city  \
# 56433               Kings XI Punjab          Chennai Super Kings  Dharamsala
# 27677         Kolkata Knight Riders          Chennai Super Kings   Centurion
# 115840  Royal Challengers Bangalore             Rajasthan Royals   Bengaluru
# 114085        Kolkata Knight Riders  Royal Challengers Bangalore     Kolkata
# 99273           Chennai Super Kings               Mumbai Indians      Mumbai
# ...                             ...                          ...         ...
# 23285               Kings XI Punjab  Royal Challengers Bangalore      Durban
# 126401          Chennai Super Kings          Sunrisers Hyderabad      Mumbai
# 7925                 Gujarat Titans              Kings XI Punjab  Chandigarh
# 101816        Kolkata Knight Riders          Sunrisers Hyderabad   Hyderabad
# 136088               Delhi Capitals              Kings XI Punjab       Delhi
#
# ...

# %%
X_train['batting_team'].unique()
# Out:
# array(['Kings XI Punjab', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Mumbai Indians', 'Sunrisers Hyderabad',
#        'Delhi Capitals', 'Gujarat Titans', 'Lucknow Super Giants'],
#       dtype=object)

# %% [markdown]
# **Here three column batting_team, bowling_team and city are in string form it will create problen so we apply one-Hot-encoding**

# %% [markdown]
# **One-Hot-encoding**

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse = False, drop = 'first'), ['batting_team', 'bowling_team', 'city'])
], remainder = 'passthrough')

# %% [markdown]
# **Now we make a pipeline in which **
#
# **1. Transformation**
#
# **2. Apply Logistic regression**

# %% [markdown]
# **Import Logistic regression and pipeline**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %% [markdown]
# **Create a pipe object**

# %%
pipe_ipl = Pipeline(steps = [
    ('step1', trf),
    ('step2', LogisticRegression(solver = 'liblinear'))
])

# %% [markdown]
# **Feed the data**

# %%
pipe_ipl.fit(X_train, Y_train)
# Out:
# c:\users\sachin kumar ray\appdata\local\programs\python\python39\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %% [markdown]
# **Predict the value on testing dataset**

# %%
Y_pred = pipe_ipl.predict(X_test)

# %%
Y_pred
# Out:
# array([0, 1, 0, ..., 1, 1, 0], dtype=int64)

# %% [markdown]
# **Prediction on training dataset**

# %%
Y_pred_train = pipe_ipl.predict(X_train)

# %%
Y_pred_train
# Out:
# array([1, 1, 0, ..., 0, 1, 0], dtype=int64)

# %% [markdown]
# **Accuracy score**

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, Y_pred)
# Out:
# 0.8275810881021302

# %% [markdown]
# **Graph**

# %%
from sklearn.metrics import roc_curve, precision_recall_curve, auc
# ROC Curve
fpr_train, tpr_train, _ = roc_curve(Y_train, Y_pred_train)
fpr_test, tpr_test, _ = roc_curve(Y_test, Y_pred)

# %%
fpr_train
# Out:
# array([0.        , 0.17290975, 1.        ])

# %%
tpr_train
# Out:
# array([0.        , 0.83361988, 1.        ])

# %%
fpr_test
# Out:
# array([0.        , 0.17956266, 1.        ])

# %%
tpr_test
# Out:
# array([0.        , 0.83562076, 1.        ])

# %%
# Plot ROC Curves
from matplotlib import pyplot as plt
plt.figure(figsize=(8, 6))
plt.plot(fpr_train, tpr_train, label='Train ROC Curve')
plt.plot(fpr_test, tpr_test, label='Test ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
# Precision-Recall Curve
precision_train, recall_train, _ = precision_recall_curve(Y_train, Y_pred_train)
precision_test, recall_test, _ = precision_recall_curve(Y_test, Y_pred)

# %%
# Plot Precision-Recall Curves
plt.figure(figsize=(8, 6))
plt.plot(recall_train, precision_train, label='Train Precision-Recall Curve')
plt.plot(recall_test, precision_test, label='Test Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.show()

# %% [markdown]
# **Prediction**

# %%
pipe_ipl.predict_proba(X_test)[250]
# Out:
# array([0.35159234, 0.64840766])

# %% [markdown]
# **we fit the model with a whole match scanerio, logistic regression gives bettrr probablity so we feed the 2nd inning data**

# %% [markdown]
# **This will give probabilty of winning and lossiing a match at the end of every over**

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wicket_left','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wicket_left'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivery_df,74,pipe_ipl)
temp_df
# Out:
# Target- 179
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 12399            1                4                0  58.4  41.6
# 12407            2                8                0  54.7  45.3
# 12413            3                1                0  59.5  40.5
# 12419            4                7                1  69.8  30.2
# 12425            5               12                0  61.8  38.2
# 12431            6               13                0  51.8  48.2
# 12437            7                9                0  46.6  53.4
# 12445            8               15                0  34.2  65.8
# 12451            9                7                0  31.9  68.1
# 12458           10               17                0  19.9  80.1
# 12464           11                9                1  25.9  74.1
# 12470           12                9                0  22.0  78.0
# 12476           13                8                0  19.4  80.6
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,4))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-179')

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Gujarat Titans',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals',
#  'Lucknow Super Giants']

# %%
delivery_df['city'].unique()
# Out:
# array(['Hyderabad', 'Rajkot', 'Bangalore', 'Mumbai', 'Indore', 'Kolkata',
#        'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai', 'Cape Town',
#        'Port Elizabeth', 'Durban', 'Centurion', 'East London',
#        'Johannesburg', 'Kimberley', 'Bloemfontein', 'Ahmedabad',
#        'Dharamsala', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah',
#        nan, 'Cuttack', 'Visakhapatnam', 'Mohali', 'Bengaluru'],
#       dtype=object)

# %%
import pickle
pickle.dump(pipe_ipl,open('ipl-second-inning-win-prob-prediction.pkl','wb'))

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.1
